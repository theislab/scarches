# %% [markdown]
# # Unsupervised surgery pipeline with TRVAE

# %%
import os
import timeit
os.chdir('../')
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
import scanpy as sc
import torch
import scarches as sca
from scarches.dataset.trvae.data_handling import remove_sparsity
import matplotlib.pyplot as plt
import numpy as np
import gdown
# Out:
# Global seed set to 0

# %%
sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %% [markdown]
# ### Set relevant anndata.obs labels and training length
#
# Here we use the CelSeq2 and SS2 studies as query data and the other 3 studies as reference atlas. We strongly suggest to use earlystopping to avoid over-fitting. The best earlystopping criteria is the 'val_unweighted_loss' for TRVAE.

# %%
condition_key = 'batch'
target_conditions = ["10X"]


trvae_epochs = 500
surgery_epochs = 500

early_stopping_kwargs = {
    "early_stopping_metric": "val_unweighted_loss",
    "threshold": 0,
    "patience": 20,
    "reduce_lr": True,
    "lr_patience": 13,
    "lr_factor": 0.1,
}

# %% [markdown]
# ### Download Dataset and split into reference dataset and query dataset

# %%
url = 'https://drive.google.com/uc?id=1Vh6RpYkusbGIZQC8GMFe3OKVDk5PWEpC'
output = 'pbmc.h5ad'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Vh6RpYkusbGIZQC8GMFe3OKVDk5PWEpC
# To: c:\Helmholtz\scarches\notebooks\pbmc.h5ad
# 100%|██████████| 2.06G/2.06G [07:55<00:00, 4.34MB/s]
# 'pbmc.h5ad'

# %%
adata = sc.read('pbmc.h5ad')

# %%
adata.X = adata.layers["counts"].copy()

# %% [markdown]
# This line makes sure that count data is in the adata.X. Remember that count data in adata.X is necessary when using "nb" or "zinb" loss. However, when using trVAE with MSE loss normalized data is necessary in adata.X

# %%
# adata = remove_sparsity(adata)
source_adata = adata[~adata.obs[condition_key].isin(target_conditions)]
source_adata.raw = source_adata
target_adata = adata[adata.obs[condition_key].isin(target_conditions)]
source_conditions = source_adata.obs[condition_key].unique().tolist()

# %%
source_adata
# Out:
# AnnData object with n_obs × n_vars = 22779 × 12303
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue'
#     layers: 'counts'

# %%
target_adata
# Out:
# View of AnnData object with n_obs × n_vars = 10727 × 12303
#     obs: 'batch', 'chemistry', 'data_type', 'dpt_pseudotime', 'final_annotation', 'mt_frac', 'n_counts', 'n_genes', 'sample_ID', 'size_factors', 'species', 'study', 'tissue'
#     layers: 'counts'

# %%
sc.pp.normalize_total(source_adata)

# %%
# sc.pp.log1p(source_adata)

# %% [markdown]
# ### Create TRVAE model and train it on reference dataset

# %% [markdown]
# Create the trVAE model instance with NB loss as default. Insert "recon_loss='mse'," or "recon_loss='zinb'," to change the reconstruction loss.

# %%
trvae = sca.models.TRVAE(
    adata=source_adata,
    condition_key=condition_key,
    conditions=source_conditions,
    hidden_layer_sizes=[128, 128],
)
# Out:
# INITIALIZING NEW NETWORK..............
# Encoder Architecture:
# 	Input Layer in, out and cond: 12303 128 9
# 	Hidden Layer 1 in/out: 128 128
# 	Mean/Var Layer in/out: 128 10
# Decoder Architecture:
# 	First Layer in, out and cond:  10 128 9
# 	Hidden Layer 1 in/out: 128 128
# 	Output Layer in/out:  128 12303

# %%
trvae.train(
    n_epochs=10,
    alpha_epoch_anneal=1,
    early_stopping_kwargs=early_stopping_kwargs
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 trvae.train(
#       2     n_epochs=10,
#       3     alpha_epoch_anneal=1,
#       4     early_stopping_kwargs=early_stopping_kwargs
#       5 )
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\models\trvae\trvae_model.py:137, in TRVAE.train(self, n_epochs, lr, eps, **kwargs)
#     119 """Train the model.
#     120
#     121    Parameters
#    (...)
#     130         kwargs for the TrVAE trainer.
#     131 """
#     132 self.trainer = trVAETrainer(
#     133     self.model,
#     134     self.adata,
#     135     condition_key=self.condition_key_,
#     136     **kwargs)
# --> 137 self.trainer.train(n_epochs, lr, eps)
#     138 self.is_trained_ = True
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\trainers\trvae\trainer.py:226, in Trainer.train(self, n_epochs, lr, eps)
#     223         batch_data[key] = batch.to(self.device)
#     225     # Loss Calculation
# --> 226     self.on_iteration(batch_data)
#     228 # Validation of Model, Monitoring, Early Stopping
#     229 self.on_epoch_end()
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\trainers\trvae\trainer.py:263, in Trainer.on_iteration(self, batch_data)
#     260                 module.track_running_stats = False
#     262 # Calculate Loss depending on Trainer/Model
# --> 263 self.current_loss = loss = self.loss(batch_data)
#     264 self.optimizer.zero_grad()
#     265 loss.backward()
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\trainers\trvae\unsupervised.py:63, in trVAETrainer.loss(self, total_batch)
#      62 def loss(self, total_batch=None):
# ---> 63     recon_loss, kl_loss, mmd_loss = self.model(**total_batch)
#      64     loss = recon_loss + self.calc_alpha_coeff()*kl_loss + mmd_loss
#      65     self.iter_logs["loss"].append(loss.item())
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\models\trvae\trvae.py:141, in trVAE.forward(self, x, batch, sizefactor, labeled)
#     139     dispersion = F.linear(one_hot_encoder(batch, self.n_conditions), self.theta)
#     140     dispersion = torch.exp(dispersion)
# --> 141     recon_loss = -nb(x=x, mu=dec_mean, theta=dispersion).sum(dim=-1).mean()
#     143 z1_var = torch.exp(z1_log_var) + 1e-4
#     144 kl_div = kl_divergence(
#     145     Normal(z1_mean, torch.sqrt(z1_var)),
#     146     Normal(torch.zeros_like(z1_mean), torch.ones_like(z1_var))
#     147 ).sum(dim=1).mean()
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\models\trvae\losses.py:61, in nb(x, mu, theta, eps)
#      54     theta = theta.view(1, theta.size(0))
#      56 log_theta_mu_eps = torch.log(theta + mu + eps)
#      57 res = (
#      58     theta * (torch.log(theta + eps) - log_theta_mu_eps)
#      59     + x * (torch.log(mu + eps) - log_theta_mu_eps)
#      60     + torch.lgamma(x + theta)
# ---> 61     - torch.lgamma(theta)
#      62     - torch.lgamma(x + 1)
#      63 )
#      65 return res
#
# KeyboardInterrupt:

# %% [markdown]
# ### Create anndata file of latent representation and compute UMAP

# %%
adata_latent = sc.AnnData(trvae.get_latent())
adata_latent.obs['tissue'] = source_adata.obs["tissue"].tolist()
adata_latent.obs['batch'] = source_adata.obs[condition_key].tolist()

# %%
sc.pp.neighbors(adata_latent, n_neighbors=8)
sc.tl.leiden(adata_latent)
sc.tl.umap(adata_latent)
sc.pl.umap(adata_latent,
           color=['batch', 'tissue'],
           frameon=False,
           wspace=0.6,
           )

# %% [markdown]
# After pretraining the model can be saved for later use

# %%
ref_path = 'reference_model/'
trvae.save(ref_path, overwrite=True)

# %%
#Check
print(target_adata.obs['batch'])
# Out:
# index
# AAACCCAAGCGCCCAT-1-10X    10X
# AAACCCAAGGTTCCGC-1-10X    10X
# AAACCCACAGAGTTGG-1-10X    10X
# AAACCCACAGGTATGG-1-10X    10X
# AAACCCACATAGTCAC-1-10X    10X
#                          ...
# TTTGTTGGTGCGTCGT-1-10X    10X
# TTTGTTGGTGTCATGT-1-10X    10X
# TTTGTTGGTTTGAACC-1-10X    10X
# TTTGTTGTCCAAGCCG-1-10X    10X
# TTTGTTGTCTTACTGT-1-10X    10X
# Name: batch, Length: 10727, dtype: category
# Categories (1, object): ['10X']

# %% [markdown]
# ### Perform surgery on reference model and train on query dataset

# %% [markdown]
# Executing zero-shot + timing

# %%
start_time = timeit.default_timer()
ref_model, rename_cats = trvae.zero_shot_surgery(target_adata, ref_path, copy=False)
print(f'Executed in {timeit.default_timer() - start_time} seconds')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 2
#       1 start_time = timeit.default_timer()
# ----> 2 ref_model, rename_cats = trvae.zero_shot_surgery(target_adata, ref_path, copy=False)
#       3 print(f'Executed in {timeit.default_timer() - start_time} seconds')
#
# AttributeError: 'TRVAE' object has no attribute 'zero_shot_surgery'

# %%
adata_latent = sc.AnnData(ref_model.get_latent())
adata_latent.obs['tissue'] = target_adata.obs['tissue'].tolist()
adata_latent.obs['batch'] = target_adata.obs['batch'].tolist()
#Check
print(target_adata.obs['batch'])

# %%
sc.pp.neighbors(adata_latent, n_neighbors=8)
sc.tl.leiden(adata_latent)
sc.tl.umap(adata_latent)
sc.pl.umap(adata_latent,
           color=['batch', 'tissue'],
           frameon=False,
           wspace=0.6,
           )

# %%
surg_path = 'surgery_model'
ref_model.save(surg_path, overwrite=True)

# %% [markdown]
# ### UP TO HERE

# %% [markdown]
# ### Get latent representation of reference + query dataset and compute UMAP

# %%
full_latent = sc.AnnData(ref_model.get_latent(adata.X, adata.obs[condition_key]))
full_latent.obs['tissue'] = adata.obs['tissue'].tolist()
full_latent.obs['batch'] = adata.obs[condition_key].tolist()
# Out:
# index
# AAACCTGCAGCGAACA-1-Oetjen_A      Oetjen_A
# AAACCTGCATGTCCTC-1-Oetjen_A      Oetjen_A
# AAACCTGGTCGACTGC-1-Oetjen_A      Oetjen_A
# AAACCTGGTCGCTTCT-1-Oetjen_A      Oetjen_A
# AAACCTGTCCCGACTT-1-Oetjen_A      Oetjen_A
#                                    ...
# Mono_nonclassical_S96-Villani     Villani
# Mono_nonclassical_S97-Villani     Villani
# Mono_nonclassical_S98-Villani     Villani
# Mono_nonclassical_S99-Villani     Villani
# Mono_nonclassical_S9-Villani      Villani
# Name: batch, Length: 33506, dtype: category
# Categories (10, object): ['10X', 'Freytag', 'Oetjen_A', 'Oetjen_P', ..., 'Sun_sample2_KC', 'Sun_sample3_TB', 'Sun_sample4_TC', 'Villani']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [32], line 2
#       1 print(adata.obs['batch'])
# ----> 2 full_latent = sc.AnnData(ref_model.get_latent(adata.X, adata.obs[condition_key]))
#       3 full_latent.obs['tissue'] = adata.obs['tissue'].tolist()
#       4 full_latent.obs['batch'] = adata.obs[condition_key].tolist()
#
# File c:\Users\Aleksandra Topalova\AppData\Local\Programs\Python\Python310\lib\site-packages\scarches\models\base\_base.py:296, in CVAELatentsMixin.get_latent(self, x, c, mean, mean_var)
#     294 c = np.asarray(c)
#     295 if not set(c).issubset(self.conditions_):
# --> 296     raise ValueError("Incorrect conditions")
#     297 labels = np.zeros(c.shape[0])
#     298 for condition, label in self.model.condition_encoder.items():
#
# ValueError: Incorrect conditions

# %%
sc.pp.neighbors(full_latent, n_neighbors=8)
sc.tl.leiden(full_latent)
sc.tl.umap(full_latent)
sc.pl.umap(full_latent,
           color=['batch', 'cell_type'],
           frameon=False,
           wspace=0.6,
           )
# Out:
# ... storing 'cell_type' as categorical
# ... storing 'batch' as categorical
