# %%
import scanpy as sc
import surgeon
# Out:
# Using TensorFlow backend.

# %%
sc.settings.set_figure_params(dpi=200)

# %%
condition_key = "batch"
cell_type_key = 'celltype'
target_condition = "Batch4"

# %% [markdown]
# # Loading four Toy datasets and data preparation

# %%
adata = sc.read("./data/toy/toy_count.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 20000 × 2000
#     obs: 'batch', 'celltype'

# %% [markdown]
# ## Number of cells in each batch

# %%
adata.obs[condition_key].value_counts()
# Out:
# Batch4    5000
# Batch3    5000
# Batch2    5000
# Batch1    5000
# Name: batch, dtype: int64

# %% [markdown]
# ## visualization  of the original data

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# WARNING: You're trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.pl.umap(adata, color=[condition_key, cell_type_key], wspace=0.7)

# %% [markdown]
# ## Now we leave out one study (SS2) for training the newtork

# %%
adata_for_training = adata[adata.obs[condition_key] != target_condition]
adata_for_training
# Out:
# View of AnnData object with n_obs × n_vars = 15000 × 2000
#     obs: 'batch', 'celltype'
#     uns: 'neighbors', 'batch_colors', 'celltype_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
sc.pl.umap(adata_for_training, color=[condition_key, cell_type_key], wspace=0.5)

# %%
adata_out_of_sample = adata[adata.obs[condition_key] == target_condition]
adata_out_of_sample
# Out:
# View of AnnData object with n_obs × n_vars = 5000 × 2000
#     obs: 'batch', 'celltype'
#     uns: 'neighbors', 'batch_colors', 'celltype_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ## Normalization

# %%
adata_for_training = surgeon.utils.normalize(adata_for_training, 
                                             filter_min_counts=False, 
                                             normalize_input=False, 
                                             size_factors=True,
                                             logtrans_input=True,
                                             n_top_genes=2000,
                                            )

# %%
adata_out_of_sample = surgeon.utils.normalize(adata_out_of_sample, 
                                              filter_min_counts=False, 
                                              normalize_input=False, 
                                              size_factors=True,
                                              logtrans_input=True,
                                              n_top_genes=2000,
                                             )
# Out:
# Trying to set attribute `.obs` of view, making a copy.

# %% [markdown]
# ## Train/Test Split

# %%
train_adata, valid_adata = surgeon.utils.train_test_split(adata_for_training, 0.85)

# %%
train_adata.shape, valid_adata.shape
# Out:
# ((12750, 2000), (2250, 2000))

# %%
n_conditions = len(train_adata.obs[condition_key].unique().tolist())

# %% [markdown]
# # Create & Train model with training data

# %%
network = surgeon.archs.CVAE(x_dimension=train_adata.shape[1], 
                             z_dimension=20,
                             n_conditions=n_conditions,
                             lr=0.001,
                             alpha=0.001,
                             eta=1.0,
                             clip_value=3.0,
                             loss_fn='nb',
                             model_path="./models/CVAE/Toy_count/",
                             dropout_rate=0.2
                            )
# Out:
# WARNING:tensorflow:From /home/mohsen/miniconda3/envs/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mohsen/miniconda3/envs/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /home/mohsen/scnet/surgeon/models/_cvae.py:146: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   output=h_disp)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 3)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2003)         0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          1025536     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131072      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 256)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           5140        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 20)           5140        dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 20)           0           dense_2[0][0]
#                                                                  dense_3[0][0]
# ==================================================================================================
# Total params: 1,169,960
# Trainable params: 1,168,424
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 3)            0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 23)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          5888        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 256)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          131072      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2000)         1026000     dropout_4[0][0]
# __________________________________________________________________________________________________
# decoder_mean (Activation)       (None, 2000)         0           dense_5[0][0]
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 2000)         1026000     dropout_4[0][0]
# __________________________________________________________________________________________________
# colwise_mult_layer_1 (ColwiseMu (None, 2000)         0           decoder_mean[0][0]
#                                                                  size_factor[0][0]
# __________________________________________________________________________________________________
# decoder_disp (Activation)       (None, 2000)         0           dense_6[0][0]
# __________________________________________________________________________________________________
# kl_nb (SliceLayer)              (None, 2000)         0           colwise_mult_layer_1[0][0]
#                                                                  decoder_disp[0][0]
# ==================================================================================================
# Total params: 2,192,032
# Trainable params: 2,190,496
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 3)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  1169960     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 3)            0
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2000)         2192032     encoder[1][2]
#                                                                  decoder_labels[0][0]
#                                                                  size_factor[0][0]
# ==================================================================================================
# Total params: 3,361,992
# Trainable params: 3,358,920
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %% [markdown]
# ## We assign each study to a numerical label

# %%
conditions = adata.obs[condition_key].unique().tolist()
target_conditions = [target_condition]
condition_encoder = surgeon.utils.create_dictionary(conditions, target_conditions)
condition_encoder
# Out:
# {'Batch1': 0, 'Batch2': 1, 'Batch3': 2}

# %% [markdown]
# ## Training the network

# %%
network.train(train_adata,
              valid_adata, 
              condition_key=condition_key,
              le=condition_encoder, 
              n_epochs=200,
              batch_size=128, 
              early_stop_limit=20,
              lr_reducer=15, 
              save=True, 
              verbose=2)
# Out:
# WARNING:tensorflow:From /home/mohsen/miniconda3/envs/venv/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 12750 samples, validate on 2250 samples
# Epoch 1/200
#  - 11s - loss: 4.1269 - nb: 4.1269 - val_loss: 3.0368 - val_nb: 3.0368
# Epoch 2/200
#  - 1s - loss: 2.9928 - nb: 2.9928 - val_loss: 2.9177 - val_nb: 2.9177
# Epoch 3/200
#  - 1s - loss: 2.9056 - nb: 2.9056 - val_loss: 2.8248 - val_nb: 2.8248
# Epoch 4/200
#  - 1s - loss: 2.8544 - nb: 2.8544 - val_loss: 2.7726 - val_nb: 2.7726
# Epoch 5/200
#  - 1s - loss: 2.8115 - nb: 2.8115 - val_loss: 2.7519 - val_nb: 2.7519
# Epoch 6/200
#  - 1s - loss: 2.7852 - nb: 2.7852 - val_loss: 2.7579 - val_nb: 2.7579
# Epoch 7/200
#  - 1s - loss: 2.7651 - nb: 2.7651 - val_loss: 2.7088 - val_nb: 2.7088
# Epoch 8/200
#  - 1s - loss: 2.7515 - nb: 2.7515 - val_loss: 2.7049 - val_nb: 2.7049
# Epoch 9/200
#  - 1s - loss: 2.7361 - nb: 2.7361 - val_loss: 2.6836 - val_nb: 2.6836
# Epoch 10/200
#  - 1s - loss: 2.7281 - nb: 2.7281 - val_loss: 2.6875 - val_nb: 2.6875
# Epoch 11/200
#  - 1s - loss: 2.7225 - nb: 2.7225 - val_loss: 2.6730 - val_nb: 2.6730
# Epoch 12/200
#  - 1s - loss: 2.7160 - nb: 2.7160 - val_loss: 2.6746 - val_nb: 2.6746
# Epoch 13/200
#  - 1s - loss: 2.7112 - nb: 2.7112 - val_loss: 2.6649 - val_nb: 2.6649
# Epoch 14/200
#  - 1s - loss: 2.7072 - nb: 2.7072 - val_loss: 2.6868 - val_nb: 2.6868
# Epoch 15/200
#  - 1s - loss: 2.7050 - nb: 2.7050 - val_loss: 2.6624 - val_nb: 2.6624
# Epoch 16/200
#  - 1s - loss: 2.7017 - nb: 2.7017 - val_loss: 2.6818 - val_nb: 2.6818
# Epoch 17/200
#  - 1s - loss: 2.7002 - nb: 2.7002 - val_loss: 2.6619 - val_nb: 2.6619
# Epoch 18/200
#  - 1s - loss: 2.6964 - nb: 2.6964 - val_loss: 2.6591 - val_nb: 2.6591
# Epoch 19/200
#  - 1s - loss: 2.6924 - nb: 2.6924 - val_loss: 2.6588 - val_nb: 2.6588
# Epoch 20/200
#  - 1s - loss: 2.6900 - nb: 2.6900 - val_loss: 2.6510 - val_nb: 2.6510
# Epoch 21/200
#  - 1s - loss: 2.6882 - nb: 2.6882 - val_loss: 2.6518 - val_nb: 2.6518
# Epoch 22/200
#  - 1s - loss: 2.6860 - nb: 2.6860 - val_loss: 2.6535 - val_nb: 2.6535
# Epoch 23/200
#  - 1s - loss: 2.6843 - nb: 2.6843 - val_loss: 2.6487 - val_nb: 2.6487
# Epoch 24/200
#  - 1s - loss: 2.6832 - nb: 2.6832 - val_loss: 2.6515 - val_nb: 2.6515
# Epoch 25/200
#  - 1s - loss: 2.6818 - nb: 2.6818 - val_loss: 2.6485 - val_nb: 2.6485
# Epoch 26/200
#  - 1s - loss: 2.6795 - nb: 2.6795 - val_loss: 2.6443 - val_nb: 2.6443
# Epoch 27/200
#  - 1s - loss: 2.6775 - nb: 2.6775 - val_loss: 2.6496 - val_nb: 2.6496
# Epoch 28/200
#  - 1s - loss: 2.6768 - nb: 2.6768 - val_loss: 2.6433 - val_nb: 2.6433
# Epoch 29/200
#  - 1s - loss: 2.6740 - nb: 2.6740 - val_loss: 2.6425 - val_nb: 2.6425
# Epoch 30/200
#  - 1s - loss: 2.6739 - nb: 2.6739 - val_loss: 2.6446 - val_nb: 2.6446
# Epoch 31/200
#  - 1s - loss: 2.6744 - nb: 2.6744 - val_loss: 2.6418 - val_nb: 2.6418
# Epoch 32/200
#  - 1s - loss: 2.6720 - nb: 2.6720 - val_loss: 2.6404 - val_nb: 2.6404
# Epoch 33/200
#  - 1s - loss: 2.6715 - nb: 2.6715 - val_loss: 2.6390 - val_nb: 2.6390
# Epoch 34/200
#  - 1s - loss: 2.6711 - nb: 2.6711 - val_loss: 2.6448 - val_nb: 2.6448
# Epoch 35/200
#  - 1s - loss: 2.6699 - nb: 2.6699 - val_loss: 2.6373 - val_nb: 2.6373
# Epoch 36/200
#  - 1s - loss: 2.6689 - nb: 2.6689 - val_loss: 2.6381 - val_nb: 2.6381
# Epoch 37/200
#  - 1s - loss: 2.6685 - nb: 2.6685 - val_loss: 2.6364 - val_nb: 2.6364
# Epoch 38/200
#  - 1s - loss: 2.6661 - nb: 2.6661 - val_loss: 2.6372 - val_nb: 2.6372
# Epoch 39/200
#  - 1s - loss: 2.6657 - nb: 2.6657 - val_loss: 2.6347 - val_nb: 2.6347
# Epoch 40/200
#  - 1s - loss: 2.6663 - nb: 2.6663 - val_loss: 2.6376 - val_nb: 2.6376
# Epoch 41/200
#  - 1s - loss: 2.6652 - nb: 2.6652 - val_loss: 2.6393 - val_nb: 2.6393
# Epoch 42/200
#  - 1s - loss: 2.6632 - nb: 2.6632 - val_loss: 2.6361 - val_nb: 2.6361
# Epoch 43/200
#  - 1s - loss: 2.6626 - nb: 2.6626 - val_loss: 2.6347 - val_nb: 2.6347
# Epoch 44/200
#  - 1s - loss: 2.6620 - nb: 2.6620 - val_loss: 2.6324 - val_nb: 2.6324
# Epoch 45/200
#  - 1s - loss: 2.6622 - nb: 2.6622 - val_loss: 2.6327 - val_nb: 2.6327
# Epoch 46/200
#  - 1s - loss: 2.6611 - nb: 2.6611 - val_loss: 2.6369 - val_nb: 2.6369
# Epoch 47/200
#  - 1s - loss: 2.6615 - nb: 2.6615 - val_loss: 2.6316 - val_nb: 2.6316
# Epoch 48/200
#  - 1s - loss: 2.6589 - nb: 2.6589 - val_loss: 2.6319 - val_nb: 2.6319
# Epoch 49/200
#  - 1s - loss: 2.6579 - nb: 2.6579 - val_loss: 2.6334 - val_nb: 2.6334
# Epoch 50/200
#  - 1s - loss: 2.6590 - nb: 2.6590 - val_loss: 2.6307 - val_nb: 2.6307
# Epoch 51/200
#  - 1s - loss: 2.6573 - nb: 2.6573 - val_loss: 2.6322 - val_nb: 2.6322
# Epoch 52/200
#  - 1s - loss: 2.6575 - nb: 2.6575 - val_loss: 2.6314 - val_nb: 2.6314
# Epoch 53/200
#  - 1s - loss: 2.6566 - nb: 2.6566 - val_loss: 2.6300 - val_nb: 2.6300
# Epoch 54/200
#  - 1s - loss: 2.6569 - nb: 2.6569 - val_loss: 2.6292 - val_nb: 2.6292
# Epoch 55/200
#  - 1s - loss: 2.6567 - nb: 2.6567 - val_loss: 2.6315 - val_nb: 2.6315
# Epoch 56/200
#  - 1s - loss: 2.6555 - nb: 2.6555 - val_loss: 2.6315 - val_nb: 2.6315
# Epoch 57/200
#  - 1s - loss: 2.6545 - nb: 2.6545 - val_loss: 2.6326 - val_nb: 2.6326
# Epoch 58/200
#  - 1s - loss: 2.6537 - nb: 2.6537 - val_loss: 2.6298 - val_nb: 2.6298
# Epoch 59/200
#  - 1s - loss: 2.6545 - nb: 2.6545 - val_loss: 2.6305 - val_nb: 2.6305
# Epoch 60/200
#  - 1s - loss: 2.6535 - nb: 2.6535 - val_loss: 2.6274 - val_nb: 2.6274
# Epoch 61/200
#  - 1s - loss: 2.6523 - nb: 2.6523 - val_loss: 2.6288 - val_nb: 2.6288
# Epoch 62/200
#  - 1s - loss: 2.6517 - nb: 2.6517 - val_loss: 2.6278 - val_nb: 2.6278
# Epoch 63/200
#  - 1s - loss: 2.6524 - nb: 2.6524 - val_loss: 2.6271 - val_nb: 2.6271
# Epoch 64/200
#  - 1s - loss: 2.6518 - nb: 2.6518 - val_loss: 2.6285 - val_nb: 2.6285
# Epoch 65/200
#  - 1s - loss: 2.6508 - nb: 2.6508 - val_loss: 2.6263 - val_nb: 2.6263
# Epoch 66/200
#  - 1s - loss: 2.6500 - nb: 2.6500 - val_loss: 2.6269 - val_nb: 2.6269
# Epoch 67/200
#  - 1s - loss: 2.6496 - nb: 2.6496 - val_loss: 2.6257 - val_nb: 2.6257
# Epoch 68/200
#  - 1s - loss: 2.6486 - nb: 2.6486 - val_loss: 2.6297 - val_nb: 2.6297
# Epoch 69/200
#  - 1s - loss: 2.6490 - nb: 2.6490 - val_loss: 2.6280 - val_nb: 2.6280
# Epoch 70/200
#  - 1s - loss: 2.6491 - nb: 2.6491 - val_loss: 2.6251 - val_nb: 2.6251
# Epoch 71/200
#  - 1s - loss: 2.6476 - nb: 2.6476 - val_loss: 2.6258 - val_nb: 2.6258
# Epoch 72/200
#  - 1s - loss: 2.6478 - nb: 2.6478 - val_loss: 2.6257 - val_nb: 2.6257
# Epoch 73/200
#  - 1s - loss: 2.6463 - nb: 2.6463 - val_loss: 2.6259 - val_nb: 2.6259
# Epoch 74/200
#  - 1s - loss: 2.6465 - nb: 2.6465 - val_loss: 2.6250 - val_nb: 2.6250
# Epoch 75/200
#  - 1s - loss: 2.6466 - nb: 2.6466 - val_loss: 2.6236 - val_nb: 2.6236
# Epoch 76/200
#  - 1s - loss: 2.6456 - nb: 2.6456 - val_loss: 2.6238 - val_nb: 2.6238
# Epoch 77/200
#  - 1s - loss: 2.6457 - nb: 2.6457 - val_loss: 2.6233 - val_nb: 2.6233
# Epoch 78/200
#  - 1s - loss: 2.6452 - nb: 2.6452 - val_loss: 2.6236 - val_nb: 2.6236
# Epoch 79/200
#  - 1s - loss: 2.6444 - nb: 2.6444 - val_loss: 2.6245 - val_nb: 2.6245
# Epoch 80/200
#  - 1s - loss: 2.6450 - nb: 2.6450 - val_loss: 2.6239 - val_nb: 2.6239
# Epoch 81/200
#  - 1s - loss: 2.6437 - nb: 2.6437 - val_loss: 2.6228 - val_nb: 2.6228
# Epoch 82/200
#  - 1s - loss: 2.6435 - nb: 2.6435 - val_loss: 2.6231 - val_nb: 2.6231
# Epoch 83/200
#  - 1s - loss: 2.6425 - nb: 2.6425 - val_loss: 2.6229 - val_nb: 2.6229
# Epoch 84/200
#  - 1s - loss: 2.6426 - nb: 2.6426 - val_loss: 2.6232 - val_nb: 2.6232
# Epoch 85/200
#  - 1s - loss: 2.6425 - nb: 2.6425 - val_loss: 2.6231 - val_nb: 2.6231
# Epoch 86/200
#  - 1s - loss: 2.6419 - nb: 2.6419 - val_loss: 2.6238 - val_nb: 2.6238
# Epoch 87/200
#  - 1s - loss: 2.6415 - nb: 2.6415 - val_loss: 2.6214 - val_nb: 2.6214
# Epoch 88/200
#  - 1s - loss: 2.6407 - nb: 2.6407 - val_loss: 2.6221 - val_nb: 2.6221
# Epoch 89/200
#  - 1s - loss: 2.6400 - nb: 2.6400 - val_loss: 2.6216 - val_nb: 2.6216
# Epoch 90/200
#  - 1s - loss: 2.6402 - nb: 2.6402 - val_loss: 2.6238 - val_nb: 2.6238
# Epoch 91/200
#  - 1s - loss: 2.6402 - nb: 2.6402 - val_loss: 2.6209 - val_nb: 2.6209
# Epoch 92/200
#  - 1s - loss: 2.6392 - nb: 2.6392 - val_loss: 2.6215 - val_nb: 2.6215
# Epoch 93/200
#  - 1s - loss: 2.6391 - nb: 2.6391 - val_loss: 2.6206 - val_nb: 2.6206
# Epoch 94/200
#  - 1s - loss: 2.6388 - nb: 2.6388 - val_loss: 2.6222 - val_nb: 2.6222
# Epoch 95/200
#  - 1s - loss: 2.6380 - nb: 2.6380 - val_loss: 2.6202 - val_nb: 2.6202
# Epoch 96/200
#  - 1s - loss: 2.6383 - nb: 2.6383 - val_loss: 2.6206 - val_nb: 2.6206
# Epoch 97/200
#  - 1s - loss: 2.6375 - nb: 2.6375 - val_loss: 2.6194 - val_nb: 2.6194
# Epoch 98/200
#  - 1s - loss: 2.6377 - nb: 2.6377 - val_loss: 2.6203 - val_nb: 2.6203
# Epoch 99/200
#  - 1s - loss: 2.6372 - nb: 2.6372 - val_loss: 2.6201 - val_nb: 2.6201
# Epoch 100/200
#  - 1s - loss: 2.6367 - nb: 2.6367 - val_loss: 2.6206 - val_nb: 2.6206
# Epoch 101/200
#  - 1s - loss: 2.6368 - nb: 2.6368 - val_loss: 2.6189 - val_nb: 2.6189
# Epoch 102/200
#  - 1s - loss: 2.6366 - nb: 2.6366 - val_loss: 2.6180 - val_nb: 2.6180
# Epoch 103/200
#  - 1s - loss: 2.6365 - nb: 2.6365 - val_loss: 2.6191 - val_nb: 2.6191
# Epoch 104/200
#  - 1s - loss: 2.6353 - nb: 2.6353 - val_loss: 2.6183 - val_nb: 2.6183
# Epoch 105/200
#  - 1s - loss: 2.6354 - nb: 2.6354 - val_loss: 2.6188 - val_nb: 2.6188
# Epoch 106/200
#  - 1s - loss: 2.6356 - nb: 2.6356 - val_loss: 2.6182 - val_nb: 2.6182
# Epoch 107/200
#  - 1s - loss: 2.6348 - nb: 2.6348 - val_loss: 2.6185 - val_nb: 2.6185
# Epoch 108/200
#  - 1s - loss: 2.6347 - nb: 2.6347 - val_loss: 2.6170 - val_nb: 2.6170
# Epoch 109/200
#  - 1s - loss: 2.6350 - nb: 2.6350 - val_loss: 2.6184 - val_nb: 2.6184
# Epoch 110/200
#  - 1s - loss: 2.6349 - nb: 2.6349 - val_loss: 2.6183 - val_nb: 2.6183
# Epoch 111/200
#  - 1s - loss: 2.6345 - nb: 2.6345 - val_loss: 2.6172 - val_nb: 2.6172
# Epoch 112/200
#  - 1s - loss: 2.6341 - nb: 2.6341 - val_loss: 2.6183 - val_nb: 2.6183
# Epoch 113/200
#  - 1s - loss: 2.6341 - nb: 2.6341 - val_loss: 2.6172 - val_nb: 2.6172
# Epoch 114/200
#  - 1s - loss: 2.6341 - nb: 2.6341 - val_loss: 2.6177 - val_nb: 2.6177
# Epoch 115/200
#  - 1s - loss: 2.6340 - nb: 2.6340 - val_loss: 2.6185 - val_nb: 2.6185
# Epoch 116/200
#  - 1s - loss: 2.6339 - nb: 2.6339 - val_loss: 2.6176 - val_nb: 2.6176
# Epoch 117/200
#  - 1s - loss: 2.6339 - nb: 2.6339 - val_loss: 2.6172 - val_nb: 2.6172
# Epoch 118/200
#  - 1s - loss: 2.6334 - nb: 2.6334 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 119/200
#  - 1s - loss: 2.6333 - nb: 2.6333 - val_loss: 2.6166 - val_nb: 2.6166
# Epoch 120/200
#  - 1s - loss: 2.6331 - nb: 2.6331 - val_loss: 2.6171 - val_nb: 2.6171
# Epoch 121/200
#  - 1s - loss: 2.6332 - nb: 2.6332 - val_loss: 2.6166 - val_nb: 2.6166
# Epoch 122/200
#  - 1s - loss: 2.6330 - nb: 2.6330 - val_loss: 2.6166 - val_nb: 2.6166
# Epoch 123/200
#  - 1s - loss: 2.6327 - nb: 2.6327 - val_loss: 2.6159 - val_nb: 2.6159
# Epoch 124/200
#  - 1s - loss: 2.6326 - nb: 2.6326 - val_loss: 2.6178 - val_nb: 2.6178
# Epoch 125/200
#  - 1s - loss: 2.6327 - nb: 2.6327 - val_loss: 2.6165 - val_nb: 2.6165
# Epoch 126/200
#  - 1s - loss: 2.6322 - nb: 2.6322 - val_loss: 2.6176 - val_nb: 2.6176
# Epoch 127/200
#  - 1s - loss: 2.6325 - nb: 2.6325 - val_loss: 2.6167 - val_nb: 2.6167
# Epoch 128/200
#  - 1s - loss: 2.6323 - nb: 2.6323 - val_loss: 2.6161 - val_nb: 2.6161
# Epoch 129/200
#  - 1s - loss: 2.6323 - nb: 2.6323 - val_loss: 2.6160 - val_nb: 2.6160
# Epoch 130/200
#  - 1s - loss: 2.6321 - nb: 2.6321 - val_loss: 2.6164 - val_nb: 2.6164
# Epoch 131/200
#  - 1s - loss: 2.6319 - nb: 2.6319 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 132/200
#  - 1s - loss: 2.6321 - nb: 2.6321 - val_loss: 2.6153 - val_nb: 2.6153
# Epoch 133/200
#  - 1s - loss: 2.6318 - nb: 2.6318 - val_loss: 2.6152 - val_nb: 2.6152
# Epoch 134/200
#  - 1s - loss: 2.6319 - nb: 2.6319 - val_loss: 2.6153 - val_nb: 2.6153
# Epoch 135/200
#  - 1s - loss: 2.6316 - nb: 2.6316 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 136/200
#  - 1s - loss: 2.6313 - nb: 2.6313 - val_loss: 2.6158 - val_nb: 2.6158
# Epoch 137/200
#  - 1s - loss: 2.6318 - nb: 2.6318 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 138/200
#  - 1s - loss: 2.6316 - nb: 2.6316 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 139/200
#  - 1s - loss: 2.6312 - nb: 2.6312 - val_loss: 2.6157 - val_nb: 2.6157
# Epoch 140/200
#  - 1s - loss: 2.6308 - nb: 2.6308 - val_loss: 2.6164 - val_nb: 2.6164
# Epoch 141/200
#  - 1s - loss: 2.6311 - nb: 2.6311 - val_loss: 2.6160 - val_nb: 2.6160
# Epoch 142/200
#  - 1s - loss: 2.6311 - nb: 2.6311 - val_loss: 2.6163 - val_nb: 2.6163
# Epoch 143/200
#  - 1s - loss: 2.6312 - nb: 2.6312 - val_loss: 2.6158 - val_nb: 2.6158
# Epoch 144/200
#  - 1s - loss: 2.6305 - nb: 2.6305 - val_loss: 2.6158 - val_nb: 2.6158
# Epoch 145/200
#  - 1s - loss: 2.6305 - nb: 2.6305 - val_loss: 2.6151 - val_nb: 2.6151
# Epoch 146/200
#  - 1s - loss: 2.6306 - nb: 2.6306 - val_loss: 2.6146 - val_nb: 2.6146
# Epoch 147/200
#  - 1s - loss: 2.6301 - nb: 2.6301 - val_loss: 2.6145 - val_nb: 2.6145
# Epoch 148/200
#  - 1s - loss: 2.6302 - nb: 2.6302 - val_loss: 2.6147 - val_nb: 2.6147
# Epoch 149/200
#  - 1s - loss: 2.6302 - nb: 2.6302 - val_loss: 2.6146 - val_nb: 2.6146
# Epoch 150/200
#  - 1s - loss: 2.6299 - nb: 2.6299 - val_loss: 2.6143 - val_nb: 2.6143
# Epoch 151/200
#  - 1s - loss: 2.6300 - nb: 2.6300 - val_loss: 2.6151 - val_nb: 2.6151
# Epoch 152/200
#  - 1s - loss: 2.6301 - nb: 2.6301 - val_loss: 2.6150 - val_nb: 2.6150
# Epoch 153/200
#  - 1s - loss: 2.6300 - nb: 2.6300 - val_loss: 2.6147 - val_nb: 2.6147
# Epoch 154/200
#  - 1s - loss: 2.6297 - nb: 2.6297 - val_loss: 2.6140 - val_nb: 2.6140
# Epoch 155/200
#  - 1s - loss: 2.6297 - nb: 2.6297 - val_loss: 2.6143 - val_nb: 2.6143
# Epoch 156/200
#  - 1s - loss: 2.6298 - nb: 2.6298 - val_loss: 2.6143 - val_nb: 2.6143
# Epoch 157/200
#  - 1s - loss: 2.6294 - nb: 2.6294 - val_loss: 2.6150 - val_nb: 2.6150
# Epoch 158/200
#  - 1s - loss: 2.6294 - nb: 2.6294 - val_loss: 2.6153 - val_nb: 2.6153
# Epoch 159/200
#  - 1s - loss: 2.6297 - nb: 2.6297 - val_loss: 2.6141 - val_nb: 2.6141
# Epoch 160/200
#  - 1s - loss: 2.6297 - nb: 2.6297 - val_loss: 2.6144 - val_nb: 2.6144
# Epoch 161/200
#  - 1s - loss: 2.6292 - nb: 2.6292 - val_loss: 2.6152 - val_nb: 2.6152
# Epoch 162/200
#  - 1s - loss: 2.6294 - nb: 2.6294 - val_loss: 2.6154 - val_nb: 2.6154
# Epoch 163/200
#  - 1s - loss: 2.6294 - nb: 2.6294 - val_loss: 2.6143 - val_nb: 2.6143
# Epoch 164/200
#  - 1s - loss: 2.6290 - nb: 2.6290 - val_loss: 2.6141 - val_nb: 2.6141
# Epoch 165/200
#  - 1s - loss: 2.6289 - nb: 2.6289 - val_loss: 2.6140 - val_nb: 2.6140
# Epoch 166/200
#  - 1s - loss: 2.6289 - nb: 2.6289 - val_loss: 2.6133 - val_nb: 2.6133
# Epoch 167/200
#  - 1s - loss: 2.6290 - nb: 2.6290 - val_loss: 2.6140 - val_nb: 2.6140
# Epoch 168/200
#  - 1s - loss: 2.6292 - nb: 2.6292 - val_loss: 2.6144 - val_nb: 2.6144
# Epoch 169/200
#  - 1s - loss: 2.6292 - nb: 2.6292 - val_loss: 2.6144 - val_nb: 2.6144
# Epoch 170/200
#  - 1s - loss: 2.6285 - nb: 2.6285 - val_loss: 2.6134 - val_nb: 2.6134
# Epoch 171/200
#  - 1s - loss: 2.6288 - nb: 2.6288 - val_loss: 2.6140 - val_nb: 2.6140
# Epoch 172/200
#  - 1s - loss: 2.6286 - nb: 2.6286 - val_loss: 2.6148 - val_nb: 2.6148
# Epoch 173/200
#  - 1s - loss: 2.6286 - nb: 2.6286 - val_loss: 2.6136 - val_nb: 2.6136
# Epoch 174/200
#  - 1s - loss: 2.6281 - nb: 2.6281 - val_loss: 2.6130 - val_nb: 2.6130
# Epoch 175/200
#  - 1s - loss: 2.6283 - nb: 2.6283 - val_loss: 2.6137 - val_nb: 2.6137
# Epoch 176/200
#  - 1s - loss: 2.6283 - nb: 2.6283 - val_loss: 2.6139 - val_nb: 2.6139
# Epoch 177/200
#  - 1s - loss: 2.6280 - nb: 2.6280 - val_loss: 2.6145 - val_nb: 2.6145
# Epoch 178/200
#  - 1s - loss: 2.6280 - nb: 2.6280 - val_loss: 2.6136 - val_nb: 2.6136
# Epoch 179/200
#  - 1s - loss: 2.6281 - nb: 2.6281 - val_loss: 2.6133 - val_nb: 2.6133
# Epoch 180/200
#  - 1s - loss: 2.6279 - nb: 2.6279 - val_loss: 2.6135 - val_nb: 2.6135
# Epoch 181/200
#  - 1s - loss: 2.6278 - nb: 2.6278 - val_loss: 2.6144 - val_nb: 2.6144
# Epoch 182/200
#  - 1s - loss: 2.6278 - nb: 2.6278 - val_loss: 2.6138 - val_nb: 2.6138
# Epoch 183/200
#  - 1s - loss: 2.6279 - nb: 2.6279 - val_loss: 2.6136 - val_nb: 2.6136
# Epoch 184/200
#  - 1s - loss: 2.6277 - nb: 2.6277 - val_loss: 2.6128 - val_nb: 2.6128
# Epoch 185/200
#  - 1s - loss: 2.6273 - nb: 2.6273 - val_loss: 2.6127 - val_nb: 2.6127
# Epoch 186/200
#  - 1s - loss: 2.6277 - nb: 2.6277 - val_loss: 2.6130 - val_nb: 2.6130
# Epoch 187/200
#  - 1s - loss: 2.6274 - nb: 2.6274 - val_loss: 2.6133 - val_nb: 2.6133
# Epoch 188/200
#  - 1s - loss: 2.6274 - nb: 2.6274 - val_loss: 2.6131 - val_nb: 2.6131
# Epoch 189/200
#  - 1s - loss: 2.6275 - nb: 2.6275 - val_loss: 2.6135 - val_nb: 2.6135
# Epoch 190/200
#  - 1s - loss: 2.6271 - nb: 2.6271 - val_loss: 2.6131 - val_nb: 2.6131
# Epoch 191/200
#  - 1s - loss: 2.6273 - nb: 2.6273 - val_loss: 2.6132 - val_nb: 2.6132
# Epoch 192/200
#  - 1s - loss: 2.6276 - nb: 2.6276 - val_loss: 2.6147 - val_nb: 2.6147
# Epoch 193/200
#  - 1s - loss: 2.6272 - nb: 2.6272 - val_loss: 2.6127 - val_nb: 2.6127
# Epoch 194/200
#  - 1s - loss: 2.6268 - nb: 2.6268 - val_loss: 2.6130 - val_nb: 2.6130
# Epoch 195/200
#  - 1s - loss: 2.6270 - nb: 2.6270 - val_loss: 2.6130 - val_nb: 2.6130
# Epoch 196/200
#  - 1s - loss: 2.6273 - nb: 2.6273 - val_loss: 2.6134 - val_nb: 2.6134
# Epoch 197/200
#  - 1s - loss: 2.6269 - nb: 2.6269 - val_loss: 2.6136 - val_nb: 2.6136
# Epoch 198/200
#  - 1s - loss: 2.6266 - nb: 2.6266 - val_loss: 2.6135 - val_nb: 2.6135
# Epoch 199/200
#  - 1s - loss: 2.6269 - nb: 2.6269 - val_loss: 2.6134 - val_nb: 2.6134
# Epoch 200/200
#  - 1s - loss: 2.6266 - nb: 2.6266 - val_loss: 2.6126 - val_nb: 2.6126

# %%
network.condition_encoder
# Out:
# {'Batch1': 0, 'Batch2': 1, 'Batch3': 2}

# %%
encoder_labels, _ = surgeon.utils.label_encoder(
    train_adata, label_encoder=network.condition_encoder, condition_key=condition_key)

# %%
latent_adata = network.to_latent(train_adata, encoder_labels)
latent_adata
# Out:
# AnnData object with n_obs × n_vars = 12750 × 20
#     obs: 'batch', 'celltype', 'n_counts', 'size_factors'

# %%
sc.pp.neighbors(latent_adata)
sc.tl.umap(latent_adata)
# Out:
# /home/mohsen/.local/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 4 separate connected components using meta-embedding (experimental)
#   n_components

# %%
sc.pl.umap(latent_adata, color=[condition_key, cell_type_key], wspace=0.5)

# %% [markdown]
# # Perfroming architecture Surgery

# %%
new_network = surgeon.operate(network, 
                              new_condition=target_condition,
                              init='Xavier', 
                              freeze=True)
# Out:
# /home/mohsen/scnet/surgeon/models/_cvae.py:146: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   output=h_disp)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2004)         0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          1026048     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          131072      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256)          1024        dense_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 256)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 20)           0           dense_8[0][0]
#                                                                  dense_9[0][0]
# ==================================================================================================
# Total params: 1,170,472
# Trainable params: 1,168,936
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          6144        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          131072      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512)          2048        dense_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 512)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2000)         1026000     dropout_8[0][0]
# __________________________________________________________________________________________________
# decoder_mean (Activation)       (None, 2000)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2000)         1026000     dropout_8[0][0]
# __________________________________________________________________________________________________
# colwise_mult_layer_2 (ColwiseMu (None, 2000)         0           decoder_mean[1][0]
#                                                                  size_factor[0][0]
# __________________________________________________________________________________________________
# decoder_disp (Activation)       (None, 2000)         0           dense_12[0][0]
# __________________________________________________________________________________________________
# kl_nb (SliceLayer)              (None, 2000)         0           colwise_mult_layer_2[0][0]
#                                                                  decoder_disp[1][0]
# ==================================================================================================
# Total params: 2,192,288
# Trainable params: 2,190,752
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  1170472     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2000)         2192288     encoder[1][2]
#                                                                  decoder_labels[0][0]
#                                                                  size_factor[0][0]
# ==================================================================================================
# Total params: 3,362,760
# Trainable params: 3,359,688
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2004)         0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          1026048     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          131072      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256)          1024        dense_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 256)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 20)           0           dense_8[0][0]
#                                                                  dense_9[0][0]
# ==================================================================================================
# Total params: 1,170,472
# Trainable params: 1,026,048
# Non-trainable params: 144,424
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          6144        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          131072      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512)          2048        dense_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 512)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2000)         1026000     dropout_8[0][0]
# __________________________________________________________________________________________________
# decoder_mean (Activation)       (None, 2000)         0           dense_11[0][0]
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 2000)         1026000     dropout_8[0][0]
# __________________________________________________________________________________________________
# colwise_mult_layer_2 (ColwiseMu (None, 2000)         0           decoder_mean[1][0]
#                                                                  size_factor[0][0]
# __________________________________________________________________________________________________
# decoder_disp (Activation)       (None, 2000)         0           dense_12[0][0]
# __________________________________________________________________________________________________
# kl_nb (SliceLayer)              (None, 2000)         0           colwise_mult_layer_2[0][0]
#                                                                  decoder_disp[1][0]
# ==================================================================================================
# Total params: 2,192,288
# Trainable params: 6,144
# Non-trainable params: 2,186,144
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2000)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  1170472     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# size_factor (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2000)         2192288     encoder[1][2]
#                                                                  decoder_labels[0][0]
#                                                                  size_factor[0][0]
# ==================================================================================================
# Total params: 3,362,760
# Trainable params: 1,032,192
# Non-trainable params: 2,330,568
# __________________________________________________________________________________________________

# %%
new_network.condition_encoder
# Out:
# {'Batch1': 0, 'Batch2': 1, 'Batch3': 2, 'Batch4': 3}

# %% [markdown]
# ## Train with small new dataset containing out-of-sample condition

# %%
train_adata, valid_adata = surgeon.utils.train_test_split(adata_out_of_sample, 0.85)

# %%
train_adata.shape, valid_adata.shape
# Out:
# ((4250, 2000), (750, 2000))

# %%
new_network.train(train_adata,
                  valid_adata, 
                  condition_key=condition_key,
                  le=new_network.condition_encoder, 
                  n_epochs=100,
                  batch_size=128, 
                  early_stop_limit=25,
                  lr_reducer=20, 
                  save=True, 
                  verbose=2)
# Out:
# Train on 4250 samples, validate on 750 samples
# Epoch 1/100
#  - 1s - loss: 2.7048 - nb: 2.7048 - val_loss: 2.6816 - val_nb: 2.6816
# Epoch 2/100
#  - 0s - loss: 2.7018 - nb: 2.7018 - val_loss: 2.6837 - val_nb: 2.6837
# Epoch 3/100
#  - 0s - loss: 2.6994 - nb: 2.6994 - val_loss: 2.6799 - val_nb: 2.6799
# Epoch 4/100
#  - 0s - loss: 2.6967 - nb: 2.6967 - val_loss: 2.6792 - val_nb: 2.6792
# Epoch 5/100
#  - 0s - loss: 2.6943 - nb: 2.6943 - val_loss: 2.6842 - val_nb: 2.6842
# Epoch 6/100
#  - 0s - loss: 2.6928 - nb: 2.6928 - val_loss: 2.7018 - val_nb: 2.7018
# Epoch 7/100
#  - 0s - loss: 2.6911 - nb: 2.6911 - val_loss: 2.7036 - val_nb: 2.7036
# Epoch 8/100
#  - 0s - loss: 2.6889 - nb: 2.6889 - val_loss: 2.6986 - val_nb: 2.6986
# Epoch 9/100
#  - 0s - loss: 2.6875 - nb: 2.6875 - val_loss: 2.6843 - val_nb: 2.6843
# Epoch 10/100
#  - 0s - loss: 2.6861 - nb: 2.6861 - val_loss: 2.6782 - val_nb: 2.6782
# Epoch 11/100
#  - 0s - loss: 2.6862 - nb: 2.6862 - val_loss: 2.6762 - val_nb: 2.6762
# Epoch 12/100
#  - 0s - loss: 2.6858 - nb: 2.6858 - val_loss: 2.6758 - val_nb: 2.6758
# Epoch 13/100
#  - 0s - loss: 2.6856 - nb: 2.6856 - val_loss: 2.6767 - val_nb: 2.6767
# Epoch 14/100
#  - 0s - loss: 2.6854 - nb: 2.6854 - val_loss: 2.6778 - val_nb: 2.6778
# Epoch 15/100
#  - 0s - loss: 2.6851 - nb: 2.6851 - val_loss: 2.6777 - val_nb: 2.6777
# Epoch 16/100
#  - 0s - loss: 2.6849 - nb: 2.6849 - val_loss: 2.6778 - val_nb: 2.6778
# Epoch 17/100
#  - 0s - loss: 2.6847 - nb: 2.6847 - val_loss: 2.6775 - val_nb: 2.6775
# Epoch 18/100
#  - 0s - loss: 2.6854 - nb: 2.6854 - val_loss: 2.6780 - val_nb: 2.6780
# Epoch 19/100
#  - 0s - loss: 2.6850 - nb: 2.6850 - val_loss: 2.6756 - val_nb: 2.6756
# Epoch 20/100
#  - 0s - loss: 2.6849 - nb: 2.6849 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 21/100
#  - 0s - loss: 2.6852 - nb: 2.6852 - val_loss: 2.6764 - val_nb: 2.6764
# Epoch 22/100
#  - 0s - loss: 2.6849 - nb: 2.6849 - val_loss: 2.6747 - val_nb: 2.6747
# Epoch 23/100
#  - 0s - loss: 2.6852 - nb: 2.6852 - val_loss: 2.6750 - val_nb: 2.6750
# Epoch 24/100
#  - 0s - loss: 2.6849 - nb: 2.6849 - val_loss: 2.6761 - val_nb: 2.6761
# Epoch 25/100
#  - 0s - loss: 2.6838 - nb: 2.6838 - val_loss: 2.6748 - val_nb: 2.6748
# Epoch 26/100
#  - 0s - loss: 2.6842 - nb: 2.6842 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 27/100
#  - 0s - loss: 2.6845 - nb: 2.6845 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 28/100
#  - 0s - loss: 2.6845 - nb: 2.6845 - val_loss: 2.6754 - val_nb: 2.6754
# Epoch 29/100
#  - 0s - loss: 2.6842 - nb: 2.6842 - val_loss: 2.6747 - val_nb: 2.6747
# Epoch 30/100
#  - 0s - loss: 2.6843 - nb: 2.6843 - val_loss: 2.6748 - val_nb: 2.6748
# Epoch 31/100
#  - 0s - loss: 2.6838 - nb: 2.6838 - val_loss: 2.6750 - val_nb: 2.6750
# Epoch 32/100
#  - 0s - loss: 2.6841 - nb: 2.6841 - val_loss: 2.6753 - val_nb: 2.6753
# Epoch 33/100
#  - 0s - loss: 2.6842 - nb: 2.6842 - val_loss: 2.6745 - val_nb: 2.6745
# Epoch 34/100
#  - 0s - loss: 2.6840 - nb: 2.6840 - val_loss: 2.6743 - val_nb: 2.6743
# Epoch 35/100
#  - 0s - loss: 2.6838 - nb: 2.6838 - val_loss: 2.6758 - val_nb: 2.6758
# Epoch 36/100
#  - 0s - loss: 2.6842 - nb: 2.6842 - val_loss: 2.6759 - val_nb: 2.6759
# Epoch 37/100
#  - 0s - loss: 2.6839 - nb: 2.6839 - val_loss: 2.6750 - val_nb: 2.6750
# Epoch 38/100
#  - 0s - loss: 2.6837 - nb: 2.6837 - val_loss: 2.6762 - val_nb: 2.6762
# Epoch 39/100
#  - 0s - loss: 2.6831 - nb: 2.6831 - val_loss: 2.6765 - val_nb: 2.6765
# Epoch 40/100
#  - 0s - loss: 2.6841 - nb: 2.6841 - val_loss: 2.6759 - val_nb: 2.6759
# Epoch 41/100
#  - 0s - loss: 2.6839 - nb: 2.6839 - val_loss: 2.6762 - val_nb: 2.6762
# Epoch 42/100
#  - 0s - loss: 2.6840 - nb: 2.6840 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 43/100
#  - 0s - loss: 2.6838 - nb: 2.6838 - val_loss: 2.6739 - val_nb: 2.6739
# Epoch 44/100
#  - 0s - loss: 2.6831 - nb: 2.6831 - val_loss: 2.6750 - val_nb: 2.6750
# Epoch 45/100
#  - 0s - loss: 2.6835 - nb: 2.6835 - val_loss: 2.6745 - val_nb: 2.6745
# Epoch 46/100
#  - 0s - loss: 2.6836 - nb: 2.6836 - val_loss: 2.6755 - val_nb: 2.6755
# Epoch 47/100
#  - 0s - loss: 2.6834 - nb: 2.6834 - val_loss: 2.6748 - val_nb: 2.6748
# Epoch 48/100
#  - 0s - loss: 2.6834 - nb: 2.6834 - val_loss: 2.6758 - val_nb: 2.6758
# Epoch 49/100
#  - 0s - loss: 2.6839 - nb: 2.6839 - val_loss: 2.6752 - val_nb: 2.6752
# Epoch 50/100
#  - 0s - loss: 2.6835 - nb: 2.6835 - val_loss: 2.6750 - val_nb: 2.6750
# Epoch 51/100
#  - 0s - loss: 2.6839 - nb: 2.6839 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 52/100
#  - 0s - loss: 2.6833 - nb: 2.6833 - val_loss: 2.6752 - val_nb: 2.6752
# Epoch 53/100
#  - 0s - loss: 2.6834 - nb: 2.6834 - val_loss: 2.6754 - val_nb: 2.6754
# Epoch 54/100
#  - 0s - loss: 2.6829 - nb: 2.6829 - val_loss: 2.6768 - val_nb: 2.6768
# Epoch 55/100
#  - 0s - loss: 2.6832 - nb: 2.6832 - val_loss: 2.6774 - val_nb: 2.6774
# Epoch 56/100
#  - 0s - loss: 2.6832 - nb: 2.6832 - val_loss: 2.6796 - val_nb: 2.6796
# Epoch 57/100
#  - 0s - loss: 2.6834 - nb: 2.6834 - val_loss: 2.6784 - val_nb: 2.6784
# Epoch 58/100
#  - 0s - loss: 2.6829 - nb: 2.6829 - val_loss: 2.6772 - val_nb: 2.6772
# Epoch 59/100
#  - 0s - loss: 2.6830 - nb: 2.6830 - val_loss: 2.6769 - val_nb: 2.6769
# Epoch 60/100
#  - 0s - loss: 2.6824 - nb: 2.6824 - val_loss: 2.6772 - val_nb: 2.6772
# Epoch 61/100
#  - 0s - loss: 2.6824 - nb: 2.6824 - val_loss: 2.6779 - val_nb: 2.6779
# Epoch 62/100
#  - 0s - loss: 2.6827 - nb: 2.6827 - val_loss: 2.6767 - val_nb: 2.6767
# Epoch 63/100
#  - 0s - loss: 2.6830 - nb: 2.6830 - val_loss: 2.6778 - val_nb: 2.6778
# Epoch 64/100
#  - 0s - loss: 2.6823 - nb: 2.6823 - val_loss: 2.6762 - val_nb: 2.6762
# Epoch 65/100
#  - 0s - loss: 2.6827 - nb: 2.6827 - val_loss: 2.6754 - val_nb: 2.6754
# Epoch 66/100
#  - 0s - loss: 2.6823 - nb: 2.6823 - val_loss: 2.6751 - val_nb: 2.6751
# Epoch 67/100
#  - 0s - loss: 2.6830 - nb: 2.6830 - val_loss: 2.6748 - val_nb: 2.6748
# Epoch 68/100
#  - 0s - loss: 2.6827 - nb: 2.6827 - val_loss: 2.6748 - val_nb: 2.6748

# %%
encoder_labels, _ = surgeon.utils.label_encoder(adata, label_encoder=new_network.condition_encoder, condition_key=condition_key)
encoder_labels.shape
# Out:
# (20000, 1)

# %%
adata = surgeon.utils.normalize(adata, 
                                 filter_min_counts=False, 
                                 normalize_input=False, 
                                 size_factors=True,
                                 logtrans_input=True,
                                 n_top_genes=2000,
                                )

# %%
adata.obs[condition_key].value_counts()
# Out:
# Batch4    5000
# Batch3    5000
# Batch2    5000
# Batch1    5000
# Name: batch, dtype: int64

# %%
latent_adata = new_network.to_latent(adata, encoder_labels)
latent_adata
# Out:
# AnnData object with n_obs × n_vars = 20000 × 20
#     obs: 'batch', 'celltype', 'n_counts', 'size_factors'

# %%
sc.pp.neighbors(latent_adata)
sc.tl.umap(latent_adata)

# %%
sc.pl.umap(latent_adata, color=[condition_key, cell_type_key], wspace=0.5)
