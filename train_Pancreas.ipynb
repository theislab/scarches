# %%
import scanpy as sc
import surgeon

# %%
sc.settings.set_figure_params(dpi=200)

# %%
condition_key = "study"
cell_type_key = 'cell_type'
target_condition = "Pancreas SS2"

# %% [markdown]
# # Loading four pancrease datasets and data preparation

# %%
adata = sc.read("./data/pancreas/pancreas_normalized.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 15921 × 15369
#     obs: 'batch', 'study', 'cell_type', 'n_counts'

# %% [markdown]
# ## Number of cells in each batch

# %%
adata.obs[condition_key].value_counts()
# Out:
# Pancreas inDrop         8569
# Pancreas SS2            2989
# Pancreas CelSeq2        2449
# Pancreas Celseq         1276
# Pancreas Fluidigm C1     638
# Name: study, dtype: int64

# %% [markdown]
# ## visualization  of the original data

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# WARNING: You're trying to run this on 15369 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /home/mohsen/.local/lib/python3.6/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components

# %%
sc.pl.umap(adata, color=[condition_key, cell_type_key], wspace=0.7)

# %% [markdown]
# ## Now we leave out one study (SS2) for training the newtork

# %%
adata_for_training = adata[adata.obs[condition_key] != target_condition]
adata_for_training
# Out:
# View of AnnData object with n_obs × n_vars = 12932 × 15369
#     obs: 'batch', 'study', 'cell_type', 'n_counts'
#     uns: 'neighbors', 'study_colors', 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
sc.pl.umap(adata_for_training, color=[condition_key, cell_type_key], wspace=0.5)

# %%
adata_out_of_sample = adata[adata.obs[condition_key] == target_condition]
adata_out_of_sample
# Out:
# View of AnnData object with n_obs × n_vars = 2989 × 15369
#     obs: 'batch', 'study', 'cell_type', 'n_counts'
#     uns: 'neighbors', 'study_colors', 'cell_type_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ## Train/Test Split

# %%
train_adata, valid_adata = surgeon.utils.train_test_split(adata_for_training, 0.85)

# %%
train_adata.shape, valid_adata.shape
# Out:
# ((10992, 15369), (1940, 15369))

# %%
n_conditions = len(train_adata.obs[condition_key].unique().tolist())

# %% [markdown]
# # Create & Train model with training data

# %%
network = surgeon.archs.CVAE(x_dimension=train_adata.shape[1], 
                             z_dimension=20,
                             n_conditions=n_conditions,
                             lr=0.001,
                             alpha=0.001,
                             eta=1.0,
                             clip_value=100.0,
                             loss_fn='mse',
                             model_path="./models/CVAE/Pancreas/",
                             dropout_rate=0.2,
                             output_activation='relu')
# Out:
# WARNING:tensorflow:From /home/mohsen/miniconda3/envs/venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mohsen/miniconda3/envs/venv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 15369)        0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 15373)        0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          7870976     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131072      dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256)          1024        dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 256)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 20)           5140        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 20)           5140        dropout_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 20)           0           dense_2[0][0]
#                                                                  dense_3[0][0]
# ==================================================================================================
# Total params: 8,015,400
# Trainable params: 8,013,864
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          6144        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 256)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          131072      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512)          2048        dense_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 512)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 15369)        7884297     dropout_4[0][0]
# __________________________________________________________________________________________________
# reconstruction_output (Activati (None, 15369)        0           dense_5[0][0]
# ==================================================================================================
# Total params: 8,024,585
# Trainable params: 8,023,049
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 15369)        0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  8015400     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 15369)        8024585     encoder[1][2]
#                                                                  decoder_labels[0][0]
# ==================================================================================================
# Total params: 16,039,985
# Trainable params: 16,036,913
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %% [markdown]
# ## We assign each study to a numerical label

# %%
conditions = adata.obs[condition_key].unique().tolist()
target_conditions = [target_condition]
condition_encoder = surgeon.utils.create_dictionary(conditions, target_conditions)
condition_encoder
# Out:
# {'Pancreas inDrop': 0,
#  'Pancreas CelSeq2': 1,
#  'Pancreas Celseq': 2,
#  'Pancreas Fluidigm C1': 3}

# %% [markdown]
# ## Training the network

# %%
network.train(train_adata,
              valid_adata, 
              condition_key=condition_key,
              le=condition_encoder, 
              n_epochs=200,
              batch_size=128, 
              early_stop_limit=20,
              lr_reducer=15, 
              save=True, 
              verbose=2)

# %%
network.condition_encoder
# Out:
# {'Baron': 0, 'Muraro': 1, 'Wang': 2}

# %%
encoder_labels, _ = surgeon.utils.label_encoder(
    train_adata, label_encoder=network.condition_encoder, condition_key=condition_key)

# %%
latent_adata = network.to_latent(train_adata, encoder_labels)
latent_adata
# Out:
# AnnData object with n_obs × n_vars = 9630 × 20
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain'

# %%
sc.pp.neighbors(latent_adata)
sc.tl.umap(latent_adata)

# %%
sc.pl.umap(latent_adata, color=[condition_key, cell_type_key], wspace=0.5)

# %% [markdown]
# # Perfroming architecture Surgery

# %%
new_network = surgeon.operate(network, 
                              new_condition=target_condition,
                              init='Xavier', 
                              freeze=True)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2448)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2452)         0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          1255424     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131072      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256)          1024        dense_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 256)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20)           0           dense_7[0][0]
#                                                                  dense_8[0][0]
# ==================================================================================================
# Total params: 1,399,848
# Trainable params: 1,398,312
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          6144        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          131072      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512)          2048        dense_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 512)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 2448)         1255824     dropout_8[0][0]
# __________________________________________________________________________________________________
# reconstruction_output (ReLU)    (None, 2448)         0           dense_10[0][0]
# ==================================================================================================
# Total params: 1,396,112
# Trainable params: 1,394,576
# Non-trainable params: 1,536
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2448)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  1399848     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2448)         1396112     encoder[1][2]
#                                                                  decoder_labels[0][0]
# ==================================================================================================
# Total params: 2,795,960
# Trainable params: 2,792,888
# Non-trainable params: 3,072
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2448)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2452)         0           data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 512)          1255424     concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512)          2048        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 512)          0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          131072      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 256)          1024        dense_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 256)          0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 256)          0           leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 20)           5140        dropout_6[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 20)           0           dense_7[0][0]
#                                                                  dense_8[0][0]
# ==================================================================================================
# Total params: 1,399,848
# Trainable params: 1,255,424
# Non-trainable params: 144,424
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# latent_data (InputLayer)        (None, 20)           0
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24)           0           latent_data[0][0]
#                                                                  decoder_labels[0][0]
# __________________________________________________________________________________________________
# first_layer (Dense)             (None, 256)          6144        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 256)          1024        first_layer[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 256)          0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256)          0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 512)          131072      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 512)          2048        dense_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 512)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 2448)         1255824     dropout_8[0][0]
# __________________________________________________________________________________________________
# reconstruction_output (ReLU)    (None, 2448)         0           dense_10[0][0]
# ==================================================================================================
# Total params: 1,396,112
# Trainable params: 6,144
# Non-trainable params: 1,389,968
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 2448)         0
# __________________________________________________________________________________________________
# encoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 20), (None,  1399848     data[0][0]
#                                                                  encoder_labels[0][0]
# __________________________________________________________________________________________________
# decoder_labels (InputLayer)     (None, 4)            0
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 2448)         1396112     encoder[1][2]
#                                                                  decoder_labels[0][0]
# ==================================================================================================
# Total params: 2,795,960
# Trainable params: 1,261,568
# Non-trainable params: 1,534,392
# __________________________________________________________________________________________________

# %%
new_network.condition_encoder
# Out:
# {'Baron': 0, 'Muraro': 1, 'Wang': 2, 'Segerstolpe': 3}

# %% [markdown]
# ## Train with small new dataset containing out-of-sample condition

# %%
train_adata, valid_adata = surgeon.utils.train_test_split(adata_out_of_sample, 0.85)

# %%
train_adata.shape, valid_adata.shape
# Out:
# ((2858, 2448), (505, 2448))

# %%
new_network.train(train_adata,
                  valid_adata, 
                  condition_key=condition_key,
                  le=new_network.condition_encoder, 
                  n_epochs=100,
                  batch_size=128, 
                  early_stop_limit=25,
                  lr_reducer=20, 
                  save=True, 
                  verbose=2)
# Out:
# Train on 2858 samples, validate on 505 samples
# Epoch 1/100
#  - 1s - loss: 1078.5296 - kl_recon_loss: 1078.5296 - val_loss: 1062.5228 - val_kl_recon_loss: 1062.5228
# Epoch 2/100
#  - 0s - loss: 1063.2248 - kl_recon_loss: 1063.2248 - val_loss: 1056.5872 - val_kl_recon_loss: 1056.5872
# Epoch 3/100
#  - 0s - loss: 1057.5888 - kl_recon_loss: 1057.5888 - val_loss: 1053.5201 - val_kl_recon_loss: 1053.5201
# Epoch 4/100
#  - 0s - loss: 1053.8980 - kl_recon_loss: 1053.8980 - val_loss: 1051.6894 - val_kl_recon_loss: 1051.6894
# Epoch 5/100
#  - 0s - loss: 1051.2250 - kl_recon_loss: 1051.2250 - val_loss: 1050.4651 - val_kl_recon_loss: 1050.4651
# Epoch 6/100
#  - 0s - loss: 1048.9098 - kl_recon_loss: 1048.9098 - val_loss: 1049.4907 - val_kl_recon_loss: 1049.4907
# Epoch 7/100
#  - 0s - loss: 1047.7076 - kl_recon_loss: 1047.7076 - val_loss: 1048.7288 - val_kl_recon_loss: 1048.7288
# Epoch 8/100
#  - 0s - loss: 1046.3563 - kl_recon_loss: 1046.3563 - val_loss: 1048.1704 - val_kl_recon_loss: 1048.1704
# Epoch 9/100
#  - 0s - loss: 1044.6809 - kl_recon_loss: 1044.6809 - val_loss: 1047.7389 - val_kl_recon_loss: 1047.7389
# Epoch 10/100
#  - 0s - loss: 1043.4635 - kl_recon_loss: 1043.4635 - val_loss: 1047.2786 - val_kl_recon_loss: 1047.2786
# Epoch 11/100
#  - 0s - loss: 1042.3088 - kl_recon_loss: 1042.3088 - val_loss: 1046.9507 - val_kl_recon_loss: 1046.9507
# Epoch 12/100
#  - 0s - loss: 1041.5663 - kl_recon_loss: 1041.5663 - val_loss: 1046.4854 - val_kl_recon_loss: 1046.4854
# Epoch 13/100
#  - 0s - loss: 1041.4187 - kl_recon_loss: 1041.4187 - val_loss: 1046.3147 - val_kl_recon_loss: 1046.3147
# Epoch 14/100
#  - 0s - loss: 1039.5668 - kl_recon_loss: 1039.5668 - val_loss: 1045.8473 - val_kl_recon_loss: 1045.8473
# Epoch 15/100
#  - 0s - loss: 1039.7235 - kl_recon_loss: 1039.7235 - val_loss: 1045.6817 - val_kl_recon_loss: 1045.6817
# Epoch 16/100
#  - 0s - loss: 1038.9627 - kl_recon_loss: 1038.9627 - val_loss: 1045.0700 - val_kl_recon_loss: 1045.0700
# Epoch 17/100
#  - 0s - loss: 1038.5998 - kl_recon_loss: 1038.5998 - val_loss: 1045.0948 - val_kl_recon_loss: 1045.0948
# Epoch 18/100
#  - 0s - loss: 1037.8153 - kl_recon_loss: 1037.8153 - val_loss: 1045.0437 - val_kl_recon_loss: 1045.0437
# Epoch 19/100
#  - 0s - loss: 1037.4296 - kl_recon_loss: 1037.4296 - val_loss: 1044.6516 - val_kl_recon_loss: 1044.6516
# Epoch 20/100
#  - 0s - loss: 1037.0512 - kl_recon_loss: 1037.0512 - val_loss: 1044.5982 - val_kl_recon_loss: 1044.5982
# Epoch 21/100
#  - 0s - loss: 1037.0421 - kl_recon_loss: 1037.0421 - val_loss: 1044.6522 - val_kl_recon_loss: 1044.6522
# Epoch 22/100
#  - 0s - loss: 1036.4492 - kl_recon_loss: 1036.4492 - val_loss: 1044.1417 - val_kl_recon_loss: 1044.1417
# Epoch 23/100
#  - 0s - loss: 1036.0075 - kl_recon_loss: 1036.0075 - val_loss: 1044.1013 - val_kl_recon_loss: 1044.1013
# Epoch 24/100
#  - 0s - loss: 1035.2447 - kl_recon_loss: 1035.2447 - val_loss: 1043.9733 - val_kl_recon_loss: 1043.9733
# Epoch 25/100
#  - 0s - loss: 1035.5708 - kl_recon_loss: 1035.5708 - val_loss: 1043.8275 - val_kl_recon_loss: 1043.8275
# Epoch 26/100
#  - 0s - loss: 1034.6366 - kl_recon_loss: 1034.6366 - val_loss: 1043.7044 - val_kl_recon_loss: 1043.7044
# Epoch 27/100
#  - 0s - loss: 1034.8682 - kl_recon_loss: 1034.8682 - val_loss: 1043.4035 - val_kl_recon_loss: 1043.4035
# Epoch 28/100
#  - 0s - loss: 1034.2385 - kl_recon_loss: 1034.2385 - val_loss: 1043.5517 - val_kl_recon_loss: 1043.5517
# Epoch 29/100
#  - 0s - loss: 1034.5581 - kl_recon_loss: 1034.5581 - val_loss: 1043.4671 - val_kl_recon_loss: 1043.4671
# Epoch 30/100
#  - 0s - loss: 1034.0107 - kl_recon_loss: 1034.0107 - val_loss: 1043.4250 - val_kl_recon_loss: 1043.4250
# Epoch 31/100
#  - 0s - loss: 1033.9995 - kl_recon_loss: 1033.9995 - val_loss: 1043.6290 - val_kl_recon_loss: 1043.6290
# Epoch 32/100
#  - 0s - loss: 1033.8886 - kl_recon_loss: 1033.8886 - val_loss: 1043.3764 - val_kl_recon_loss: 1043.3764
# Epoch 33/100
#  - 0s - loss: 1033.2071 - kl_recon_loss: 1033.2071 - val_loss: 1043.2889 - val_kl_recon_loss: 1043.2889
# Epoch 34/100
#  - 0s - loss: 1033.0709 - kl_recon_loss: 1033.0709 - val_loss: 1043.6492 - val_kl_recon_loss: 1043.6492
# Epoch 35/100
#  - 0s - loss: 1032.8303 - kl_recon_loss: 1032.8303 - val_loss: 1043.3022 - val_kl_recon_loss: 1043.3022
# Epoch 36/100
#  - 0s - loss: 1032.3931 - kl_recon_loss: 1032.3931 - val_loss: 1043.2012 - val_kl_recon_loss: 1043.2012
# Epoch 37/100
#  - 0s - loss: 1033.0847 - kl_recon_loss: 1033.0847 - val_loss: 1042.8932 - val_kl_recon_loss: 1042.8932
# Epoch 38/100
#  - 0s - loss: 1032.9192 - kl_recon_loss: 1032.9192 - val_loss: 1043.0367 - val_kl_recon_loss: 1043.0367
# Epoch 39/100
#  - 0s - loss: 1032.2890 - kl_recon_loss: 1032.2890 - val_loss: 1042.8143 - val_kl_recon_loss: 1042.8143
# Epoch 40/100
#  - 0s - loss: 1032.4569 - kl_recon_loss: 1032.4569 - val_loss: 1043.1372 - val_kl_recon_loss: 1043.1372
# Epoch 41/100
#  - 0s - loss: 1032.2024 - kl_recon_loss: 1032.2024 - val_loss: 1042.8575 - val_kl_recon_loss: 1042.8575
# Epoch 42/100
#  - 0s - loss: 1031.5053 - kl_recon_loss: 1031.5053 - val_loss: 1043.2612 - val_kl_recon_loss: 1043.2612
# Epoch 43/100
#  - 0s - loss: 1031.6011 - kl_recon_loss: 1031.6011 - val_loss: 1042.9829 - val_kl_recon_loss: 1042.9829
# Epoch 44/100
#  - 0s - loss: 1031.5197 - kl_recon_loss: 1031.5197 - val_loss: 1042.8917 - val_kl_recon_loss: 1042.8917
# Epoch 45/100
#  - 0s - loss: 1031.2436 - kl_recon_loss: 1031.2436 - val_loss: 1042.9190 - val_kl_recon_loss: 1042.9190
# Epoch 46/100
#  - 0s - loss: 1031.2646 - kl_recon_loss: 1031.2646 - val_loss: 1042.6864 - val_kl_recon_loss: 1042.6864
# Epoch 47/100
#  - 0s - loss: 1031.3910 - kl_recon_loss: 1031.3910 - val_loss: 1042.8034 - val_kl_recon_loss: 1042.8034
# Epoch 48/100
#  - 0s - loss: 1030.5125 - kl_recon_loss: 1030.5125 - val_loss: 1042.8588 - val_kl_recon_loss: 1042.8588
# Epoch 49/100
#  - 0s - loss: 1030.6579 - kl_recon_loss: 1030.6579 - val_loss: 1042.9682 - val_kl_recon_loss: 1042.9682
# Epoch 50/100
#  - 0s - loss: 1031.1372 - kl_recon_loss: 1031.1372 - val_loss: 1042.9437 - val_kl_recon_loss: 1042.9437
# Epoch 51/100
#  - 0s - loss: 1031.0292 - kl_recon_loss: 1031.0292 - val_loss: 1042.6686 - val_kl_recon_loss: 1042.6686
# Epoch 52/100
#  - 0s - loss: 1030.1839 - kl_recon_loss: 1030.1839 - val_loss: 1042.5605 - val_kl_recon_loss: 1042.5605
# Epoch 53/100
#  - 0s - loss: 1030.4621 - kl_recon_loss: 1030.4621 - val_loss: 1042.6794 - val_kl_recon_loss: 1042.6794
# Epoch 54/100
#  - 0s - loss: 1030.6289 - kl_recon_loss: 1030.6289 - val_loss: 1042.6954 - val_kl_recon_loss: 1042.6954
# Epoch 55/100
#  - 0s - loss: 1030.1843 - kl_recon_loss: 1030.1843 - val_loss: 1042.6743 - val_kl_recon_loss: 1042.6743
# Epoch 56/100
#  - 0s - loss: 1030.0902 - kl_recon_loss: 1030.0902 - val_loss: 1042.6915 - val_kl_recon_loss: 1042.6915
# Epoch 57/100
#  - 0s - loss: 1030.5174 - kl_recon_loss: 1030.5174 - val_loss: 1042.3689 - val_kl_recon_loss: 1042.3689
# Epoch 58/100
#  - 0s - loss: 1030.2689 - kl_recon_loss: 1030.2689 - val_loss: 1042.6889 - val_kl_recon_loss: 1042.6889
# Epoch 59/100
#  - 0s - loss: 1029.8241 - kl_recon_loss: 1029.8241 - val_loss: 1042.7354 - val_kl_recon_loss: 1042.7354
# Epoch 60/100
#  - 0s - loss: 1030.1441 - kl_recon_loss: 1030.1441 - val_loss: 1042.5286 - val_kl_recon_loss: 1042.5286
# Epoch 61/100
#  - 0s - loss: 1029.8825 - kl_recon_loss: 1029.8825 - val_loss: 1042.2867 - val_kl_recon_loss: 1042.2867
# Epoch 62/100
#  - 0s - loss: 1030.0496 - kl_recon_loss: 1030.0496 - val_loss: 1042.1378 - val_kl_recon_loss: 1042.1378
# Epoch 63/100
#  - 0s - loss: 1029.6772 - kl_recon_loss: 1029.6772 - val_loss: 1042.5421 - val_kl_recon_loss: 1042.5421
# Epoch 64/100
#  - 0s - loss: 1029.2538 - kl_recon_loss: 1029.2538 - val_loss: 1042.5553 - val_kl_recon_loss: 1042.5553
# Epoch 65/100
#  - 0s - loss: 1029.5793 - kl_recon_loss: 1029.5793 - val_loss: 1042.4367 - val_kl_recon_loss: 1042.4367
# Epoch 66/100
#  - 0s - loss: 1029.6615 - kl_recon_loss: 1029.6615 - val_loss: 1042.4675 - val_kl_recon_loss: 1042.4675
# Epoch 67/100
#  - 0s - loss: 1029.8457 - kl_recon_loss: 1029.8457 - val_loss: 1042.6370 - val_kl_recon_loss: 1042.6370
# Epoch 68/100
#  - 0s - loss: 1029.5987 - kl_recon_loss: 1029.5987 - val_loss: 1042.6179 - val_kl_recon_loss: 1042.6179
# Epoch 69/100
#  - 0s - loss: 1029.5247 - kl_recon_loss: 1029.5247 - val_loss: 1042.8424 - val_kl_recon_loss: 1042.8424
# Epoch 70/100
#  - 0s - loss: 1029.2265 - kl_recon_loss: 1029.2265 - val_loss: 1042.2291 - val_kl_recon_loss: 1042.2291
# Epoch 71/100
#  - 0s - loss: 1029.2583 - kl_recon_loss: 1029.2583 - val_loss: 1042.5378 - val_kl_recon_loss: 1042.5378
# Epoch 72/100
#  - 0s - loss: 1029.2612 - kl_recon_loss: 1029.2612 - val_loss: 1042.2313 - val_kl_recon_loss: 1042.2313
# Epoch 73/100
#  - 0s - loss: 1029.4936 - kl_recon_loss: 1029.4936 - val_loss: 1041.8169 - val_kl_recon_loss: 1041.8169
# Epoch 74/100
#  - 0s - loss: 1028.6978 - kl_recon_loss: 1028.6978 - val_loss: 1042.2546 - val_kl_recon_loss: 1042.2546
# Epoch 75/100
#  - 0s - loss: 1028.6850 - kl_recon_loss: 1028.6850 - val_loss: 1042.1829 - val_kl_recon_loss: 1042.1829
# Epoch 76/100
#  - 0s - loss: 1029.3340 - kl_recon_loss: 1029.3340 - val_loss: 1042.3207 - val_kl_recon_loss: 1042.3207
# Epoch 77/100
#  - 0s - loss: 1028.9905 - kl_recon_loss: 1028.9905 - val_loss: 1042.1272 - val_kl_recon_loss: 1042.1272
# Epoch 78/100
#  - 0s - loss: 1028.6510 - kl_recon_loss: 1028.6510 - val_loss: 1042.0599 - val_kl_recon_loss: 1042.0599
# Epoch 79/100
#  - 0s - loss: 1029.0803 - kl_recon_loss: 1029.0803 - val_loss: 1042.5171 - val_kl_recon_loss: 1042.5171
# Epoch 80/100
#  - 0s - loss: 1028.5384 - kl_recon_loss: 1028.5384 - val_loss: 1042.4465 - val_kl_recon_loss: 1042.4465
# Epoch 81/100
#  - 0s - loss: 1028.7944 - kl_recon_loss: 1028.7944 - val_loss: 1041.9903 - val_kl_recon_loss: 1041.9903
# Epoch 82/100
#  - 0s - loss: 1028.5645 - kl_recon_loss: 1028.5645 - val_loss: 1042.5475 - val_kl_recon_loss: 1042.5475
# Epoch 83/100
#  - 0s - loss: 1028.8648 - kl_recon_loss: 1028.8648 - val_loss: 1042.3036 - val_kl_recon_loss: 1042.3036
# Epoch 84/100
#  - 0s - loss: 1028.2176 - kl_recon_loss: 1028.2176 - val_loss: 1042.1118 - val_kl_recon_loss: 1042.1118
# Epoch 85/100
#  - 0s - loss: 1028.9635 - kl_recon_loss: 1028.9635 - val_loss: 1042.1644 - val_kl_recon_loss: 1042.1644
# Epoch 86/100
#  - 0s - loss: 1028.1697 - kl_recon_loss: 1028.1697 - val_loss: 1042.3311 - val_kl_recon_loss: 1042.3311
# Epoch 87/100
#  - 0s - loss: 1027.7628 - kl_recon_loss: 1027.7628 - val_loss: 1042.0864 - val_kl_recon_loss: 1042.0864
# Epoch 88/100
#  - 0s - loss: 1028.0320 - kl_recon_loss: 1028.0320 - val_loss: 1042.0404 - val_kl_recon_loss: 1042.0404
# Epoch 89/100
#  - 0s - loss: 1028.7317 - kl_recon_loss: 1028.7317 - val_loss: 1042.2781 - val_kl_recon_loss: 1042.2781
# Epoch 90/100
#  - 0s - loss: 1028.2157 - kl_recon_loss: 1028.2157 - val_loss: 1042.3116 - val_kl_recon_loss: 1042.3116
# Epoch 91/100
#  - 0s - loss: 1027.8460 - kl_recon_loss: 1027.8460 - val_loss: 1042.2175 - val_kl_recon_loss: 1042.2175
# Epoch 92/100
#  - 0s - loss: 1028.1141 - kl_recon_loss: 1028.1141 - val_loss: 1042.1166 - val_kl_recon_loss: 1042.1166
# Epoch 93/100
#  - 0s - loss: 1027.6088 - kl_recon_loss: 1027.6088 - val_loss: 1042.3421 - val_kl_recon_loss: 1042.3421
# Epoch 94/100
#  - 0s - loss: 1028.0982 - kl_recon_loss: 1028.0982 - val_loss: 1042.1470 - val_kl_recon_loss: 1042.1470
# Epoch 95/100
#  - 0s - loss: 1027.7258 - kl_recon_loss: 1027.7258 - val_loss: 1041.9928 - val_kl_recon_loss: 1041.9928
# Epoch 96/100
#  - 0s - loss: 1027.7887 - kl_recon_loss: 1027.7887 - val_loss: 1041.9001 - val_kl_recon_loss: 1041.9001
# Epoch 97/100
#  - 0s - loss: 1027.7450 - kl_recon_loss: 1027.7450 - val_loss: 1041.8665 - val_kl_recon_loss: 1041.8665
# Epoch 98/100
#  - 0s - loss: 1028.0141 - kl_recon_loss: 1028.0141 - val_loss: 1041.8657 - val_kl_recon_loss: 1041.8657

# %%
encoder_labels, _ = surgeon.utils.label_encoder(adata, label_encoder=new_network.condition_encoder, condition_key=condition_key)

# %%
adata.obs[condition_key].value_counts()
# Out:
# Baron          8569
# Segerstolpe    3363
# Muraro         2126
# Wang            635
# Name: sample, dtype: int64

# %%
latent_adata = new_network.to_latent(adata, encoder_labels)
latent_adata
# Out:
# AnnData object with n_obs × n_vars = 14693 × 20
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain'

# %%
sc.pp.neighbors(latent_adata)
sc.tl.umap(latent_adata)

# %%
sc.pl.umap(latent_adata, color=[condition_key, cell_type_key], wspace=0.5)
